# %% [markdown]
# # Conditional

# %%
x=input("Enter your marks")
if int(x)>90:
    print("Well done, I will gift you PS5")
else:
    print("Your play time is over now, go study")

# %% [markdown]
# if can exist without else but else cannot.

# %%
x=input("Enter your marks")
if int(x)>90:
    print("Well done, I will gift you PS5")
elif int(x) > 80:
    print("Good work, you can do better, lets go on a dinner to celebrate")
else:
    print("Your play time is over now, go study")

# %%
x=input("Enter your marks") #99
if int(x)>80:#99>80  -> Yes
    print("Well done, I will gift you PS5")#Execute this
elif int(x) > 90:
    print("Good work, you can do better, lets go on a dinner to celebrate")
else:
    print("Your play time is over now, go study")

# %%
x=input("Enter your marks") 
if int(x)>90:
    if int(x) %5 ==0: #divisible by 5
        print("Well done, I will gift you BMW")
    else:
        print("Well done, I will gift you Hyundai")
elif int(x) > 80:
    print("Good work, you can do better, lets go on a dinner to celebrate")
else:
    if int(x) <40:
        print("Shit.! You failed, very bad. What happerned?")
    else:
        print("Your play time is over now, go study")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tell me the output for this
# I entered -89

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=input("Enter your marks") 
if int(x)>90:
    if int(x) %5 ==0: #divisible by 5
        print("Well done, I will gift you BMW")
    else:
        print("Well done, I will gift you Hyundai")
elif int(x) > 80:
    print("Good work, you can do better, lets go on a dinner to celebrate")
else:
    if int(x) <40:
        print("Shit.! You failed, very bad. What happerned?")
    if int(x)<30:
        print("Your play time is over now, go study")
        if int(x)<10:
            print("This is very bad")
        else:
            print("Get out of my home.")

# %% [markdown]
# # Loops
#
# Explain diff between while and for  and where to use what.

# %% [markdown]
# iterable-> sequence, 0-99

# %%
for i in range(10):
    print("I am sorry")

# %%
counter=10
while counter >0:
    print("I am sorry")
    counter=counter-1

# %%
friends=['M',"A","V","S","P"] #5 friends

print("  M: ")
for i in range(10):
    print("I am sorry")
print("  A: ")
for i in range(10):
    print("I am sorry")
print("  V: ")
for i in range(10):
    print("I am sorry")
    
print("  S: ")
for i in range(10):
    print("I am sorry")
    
print("  P ")
for i in range(10):
    print("I am sorry")

# %%
friends=['M',"A","V","S","P"] #5 friends

for person in friends:
    print(person," : ")
    for i in range(10):
        print("I am sorry")

# %%
friends=['M',"A","V","S","P"] #5 friends

for person in friends:
    print(person," : ")
    counter=10
    while counter >0:
        print("I am sorry")
        counter=counter-1

# %%
x=input("Define a range")
numbers=list(range(int(x)))

index=0

while index <len(numbers):
    print(numbers[index])
    index+=1
else:
    print("End of list reached")
    print("Lets say sorry now")
    if int(x)%5==0:
        counter=int(x)
        while counter >0:
            print("I am sorry")
            counter=counter-1

# %%
x=input("Define a range")
numbers=list(range(int(x)))

index=0

for i in numbers:
    print(numbers[index])
    index+=1
else:
    print("End of list reached")
    print("Lets say sorry now")
    if int(x)%5==0:
        counter=int(x)
        while counter >0:
            print("I am sorry")
            counter=counter-1

# %%
x=input("Define a range")
numbers=list(range(int(x)))

index=0

for i in numbers:
    if index %4==0 and index!=0:
        break
        
    print(numbers[index])
    
    index+=1
    
else:
    print("End of list reached")
    print("Lets say sorry now")
    if int(x)%5==0:
        counter=int(x)
        while counter >0:
            print("I am sorry")
            counter=counter-1

# %%
for idx,i in enumerate(["aayush","raj","ram","farq"]):
    print(idx,i)

# %%
x=input("Define a range")
numbers=list(range(int(x)))

for idx,i in enumerate(numbers):
    if idx %3==0 and idx!=0:
        continue
        
    print(i)
    
else:
    print("End of list reached")
    print("Lets say sorry now")
    if int(x)%5==0:
        counter=int(x)
        while counter >0:
            print("I am sorry")
            counter=counter-1

# %% [markdown]
# # List
# 1. Swap Functions

# %%
lt=[1,2,3,4,5,6]

# %%
lt[0]

# %%
lt[-1]

# %% [markdown]
# insert, append, extend

# %% [markdown]
# clear, delete, del

# %%
lt[:3]

# %%
lt[1:3]

# %%
lt[::2]

# %% [markdown]
# 1. Slicing
#
# list[start:end:step]
#
# 2. Concat lt +lt
# 3. Repeatation  *
# 4. Membership "IN"

# %%
2 in lt

# %%
10 in lt

# %%
lt +lt

# %%
lt*3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # List Comprehension

# %%
lt

# %%
#create a list of even numbers from lt

# way -1
even=[]
for i in lt:
    if i%2==0:
        even.append(i)

# %%
even

# %%
# smarter way
even2= [i for i in lt if i%2==0]

# %%
even2

# %%
# Create a list of first 100 Natural numbers
# Create another using list comprehension and find the numbers divisible by both 4 & 5

# %%
natural=list(range(1,101))

# %%
lst=[i for i in natural if ((i%4==0) & (i%5==0))]

# %%
[i for i in natural if ((i%4==0) & (i%5==0))]

# %%
[i for i in natural if ((i%4==0) and (i%5==0))]

# %%
# Get square of each number using comprehension for those numbers that are odd.

# %%
[i**2 for i in natural if (i%2!=0)]

# %%
# Prime numbers till 20 using list comprehension

# %%
list(range(2,21))

# %%
all([True,True,True])

# %%
all([True,True,True,False])

# %%
True and True and True and False

# %%
list(range(2,5))

# %%
for y in range(2,11):
    print(y)

# %%
for i in list(range(2,20)):
    if all( i%y != 0 for y in range(2,i)):
        print(i)

# %%
[ i for i in range(2,20) if all( i%y != 0 for y in range(2,i))] # Using list comprehension

# %% [markdown]
# # Tuples

# %% [markdown]
# ####  SAME AS LIST EXCEPT IMMUTABLE

# %%
# JIO
jio=("BROADBAND","PREPAID","POSTPAID",10,20)

# %%
type(jio)

# %%
j=(1,)

# %%
type(j)

# %%
jio[0]

# %%
jio[-1]

# %%
jio[:3]

# %%
jio[::2]

# %%
jio

# %%
lt

# %%
lt[5]=50

# %%
lt

# %%
jio[2]="PETROL-PUMP"

# %%
lt.insert(-1,100)

# %%
lt

# %%
tp=(1,2,3,[1,2,3],6)

# %%
tp[-2]=[10,20,30]

# %%
tp[-2][0]=10
tp[-2][1]=20
tp[-2][2]=30

# %%
tp + jio

# %%
jio*2

# %%
jio + [1,2,3]

# %%
jio + (1,2,3)

# %%
jio2=jio + ('BROADBAND', 'PREPAID','PREPAID','PREPAID', 'POSTPAID', 10, 20)

# %%
jio2.count("PREPAID")

# %%
len(jio2)

# %%
any(jio2)

# %%
nm=tuple([1,2,3,4,"Aayush"])

# %%
min(nm)

# %%
max(nm)

# %% [markdown]
# # Sets

# %% [markdown]
# - Collection unique elements
# - Indexing can not  be performed in set
# - Sets follow order
# - Collection of elements with different data types

# %%
set([1,2,3,4])
# Out:
# {1, 2, 3, 4}

# %%
xx={1, 2, 3, 4}

# %%
type(xx)
# Out:
# set

# %%
xx[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-c17ba70258f0> in <module>
# ----> 1 xx[0]
#
# TypeError: 'set' object is not subscriptable

# %%
xx={1, 2, 3, 4,"Aayush",True}

# %%
len(xx)
# Out:
# 5

# %%
xx.add("Vijay")

# %%
xx.add(0)

# %%
xx
# Out:
# {0, 1, 2, 3, 4, 'Aayush', 'Vijay'}

# %%
xx.add("90")

# %%
xx.add(7)

# %%
xx
# Out:
# {0, 1, 2, 3, 4, 7, '90', 'Aayush', 'Vijay'}

# %%
xx.discard('90')

# %%
xx
# Out:
# {0, 1, 2, 3, 4, 7, 'Aayush', 'Vijay'}

# %%
xy={1, 2, 3, 4}

# %%
xx.difference(xy)
# Out:
# {0, 7, 'Aayush', 'Vijay'}

# %%
xx-xy
# Out:
# {0, 7, 'Aayush', 'Vijay'}

# %%
xx.intersection(xy)
# Out:
# {1, 2, 3, 4}

# %%
#IPL
tweets=["CSK is my fav but its not performing well",
       "IPL is overrated","RCB is kill9g this time",
        "Mumbai will not reach playoffs",
       "GT and LSG is doing well in the first season","GT is unbeatable",
       "RR has a lot of ex RCB players this time","Toss is influencing results a lot"]

# %%
tweets=[i.lower() for i in tweets]

# %%
'csk is my fav but its not performing well'.split()
# Out:
# ['csk', 'is', 'my', 'fav', 'but', 'its', 'not', 'performing', 'well']

# %%
list_words=[]
for tweet in tweets:
    for word in tweet.split():
        list_words.append(word)

# %%
len(list_words)
# Out:
# 51

# %%
len(set(list_words))
# Out:
# 38

# %%
38/51
# Out:
# 0.7450980392156863

# %% [markdown]
# # Exception Handling

# %%
# Dhoni is setting a filed.
# AS BATSSMEN TRIES TO HIT A SHOT, WE WOULD LIKE A FIELDER TO CATCH IT

# %%
a=input("Enter a nuber")
print(int(a)+3)
# Out:
# Enter a nuberaayush
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-308bc2d7927a> in <module>
#       1 a=input("Enter a nuber")
# ----> 2 print(int(a)+3)
#
# ValueError: invalid literal for int() with base 10: 'aayush'

# %%
a=input("Enter a nuber")
try:
    print(int(a)+3)
except ValueError as ve:
    print("The value you entered is incorrect")
# Out:
# Enter a nuberaayush
# The value you entered is incorrect

# %% [markdown]
# #1

# %%
a=input("Enter a nuber")
try:
    print(3/int(a))
except ValueError as ve:
    print("The value you entered is incorrect")
except ZeroDivisionError as ze:
    print("Division by zero is not possible")
# Out:
# Enter a nuber0
# Division by zero is not possible

# %% [markdown]
# #2

# %%
a=input("Enter a nuber")
try:
    print(3/int(a))
except:
    print("Okay this is some error")
# Out:
# Enter a nuberaayush
# Okay this is some error

# %% [markdown]
# #3(Preffered))

# %%
a=input("Enter a nuber")
try:
    print(3/int(a))
except ValueError as ve:
    print("The value you entered is incorrect")
except ZeroDivisionError as ze:
    print("Division by zero is not possible")
except:
    print("Okay this is some error")

# %% [markdown]
# ## User Defined Exceptions

# %%
# define Python user-defined exceptions
class Error(Exception):
    """Base class for other exceptions"""
    pass


class ValueTooSmallError(Error):
    """Raised when the input value is too small"""
    pass


class ValueTooLargeError(Error):
    """Raised when the input value is too large"""
    pass


# you need to guess this number
number = 10

# user guesses a number until he/she gets it right
while True:
    try:
        i_num = int(input("Enter a number: "))
        if i_num < number:
            raise ValueTooSmallError
        elif i_num > number:
            raise ValueTooLargeError
        break
    except ValueTooSmallError:
        print("This value is too small, try again!")
        print()
    except ValueTooLargeError:
        print("This value is too large, try again!")
        print()

print("Congratulations! You guessed it correctly.")

# %% [markdown]
# # Classes

# %%
class ipl:
    
    # Initialize
    def __init__(self,year,name,location,sponsor):
        self.year=year
        self.name=name
        self.location=location
        self.sponsor=sponsor
        
    def is_favour(self):
        if self.year==2022:
            if self.name=="GT" or self.name=="RCB":
                return True
            else:
                return False
        elif self.name=="CSK":
                return True
        else:
            return False

# %%
csk=ipl(2022,"csk","Chennai","TATA")
pbk_11=ipl(2022,"pbk","Punjab","TATA")
kings_11=ipl(2021,"KXIP","Punjab","VIVO")
rcb=ipl(2022,"RCB","Banglore","TATA")

# %%
rcb.is_favour()
# Out:
# True

# %%
csk.is_favour()
# Out:
# False

# %%
csk=ipl(2021,"csk","Chennai","TATA")
csk.is_favour()
# Out:
# False

# %%
csk.year
# Out:
# 2022

# %%
csk.location
# Out:
# 'Chennai'

# %% [markdown]
# ## Inheritance

# %%
class Humans:
    def funct1(self):
        print("This is a parent  function")
        
class Women(Humans):
    def funct2(self):
        print("This is a child function")

# %%
Sarah = Women()

# %%
Sarah.funct1()
# Out:
# This is a parent  function

# %%
Sarah.funct2()
# Out:
# This is a child function

# %%
Sarah = Women()
Sarah.funct1()
Sarah.funct2()

# %%
class cricket():

    def pitch_check(self):
        return False

class ipl(cricket):
    
    # Initialize
    def __init__(self,year,name,location,sponsor):
        self.year=year
        self.name=name
        self.location=location
        self.sponsor=sponsor
        
    def is_favour(self):
        if self.year==2022:
            if self.name=="GT" or self.name=="RCB":
                return True
            else:
                return False
        elif self.name=="CSK":
                return True
        else:
            return False

# %%
del csk

# %%
csk=ipl(2021,"csk","Chennai","TATA")
csk.is_favour()
# Out:
# False

# %%
csk.pitch_check()
# Out:
# False

# %% [markdown]
# # Numpy
# 1. How to import
# 2. Numpy arrays
